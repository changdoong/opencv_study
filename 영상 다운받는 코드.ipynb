# %%
pip install yt-dlp
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2025.10.14-py3-none-any.whl.metadata (175 kB)
# Downloading yt_dlp-2025.10.14-py3-none-any.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.2 MB 229.7 kB/s eta 0:00:12
#    ------ --------------------------------- 0.5/3.2 MB 229.7 kB/s eta 0:00:12
#    ------ --------------------------------- 0.5/3.2 MB 229.7 kB/s eta 0:00:12
#    ------ --------------------------------- 0.5/3.2 MB 229.7 kB/s eta 0:00:12
#    --------- ------------------------------ 0.8/3.2 MB 244.9 kB/s eta 0:00:11
#    --------- ------------------------------ 0.8/3.2 MB 244.9 kB/s eta 0:00:11
#    ------------ --------------------------- 1.0/3.2 MB 316.5 kB/s eta 0:00:07
#    ------------ --------------------------- 1.0/3.2 MB 316.5 kB/s eta 0:00:07
#    ---------------- ----------------------- 1.3/3.2 MB 356.9 kB/s eta 0:00:06
#    ------------------- -------------------- 1.6/3.2 MB 423.6 kB/s eta 0:00:04
#    ------------------- -------------------- 1.6/3.2 MB 423.6 kB/s eta 0:00:04
#    ------------------------- -------------- 2.1/3.2 MB 501.9 kB/s eta 0:00:03
#    ------------------------- -------------- 2.1/3.2 MB 501.9 kB/s eta 0:00:03
#    ----------------------------- ---------- 2.4/3.2 MB 532.5 kB/s eta 0:00:02
#    -------------------------------- ------- 2.6/3.2 MB 563.3 kB/s eta 0:00:02
#    -------------------------------------- - 3.1/3.2 MB 645.2 kB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 654.5 kB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.10.14
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script yt-dlp.exe is installed in 'C:\Users\USER\anaconda3\envs\mch\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from yt_dlp import YoutubeDL
import os

# playlist 제거
url = "https://www.youtube.com/watch?v=xf1feLxqhDc"

download_path = r"./"

os.makedirs(download_path, exist_ok=True)

ydl_opts = {
    # 저장 경로
    'outtmpl': os.path.join(download_path, '%(title)s.%(ext)s'),

    # 가장 안정적인 포맷
    'format': 'best',

    # 재생목록 무시
    'noplaylist': True,

    # 유튜브 우회 옵션
    'extractor_args': {
        'youtube': {
            'player_client': ['android', 'web']
        }
    },

    # 브라우저 헤더
    'http_headers': {
        'User-Agent': (
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
            'AppleWebKit/537.36 (KHTML, like Gecko) '
            'Chrome/124.0 Safari/537.36'
        )
    },
}

with YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# Deprecated Feature: Support for Python version 3.9 has been deprecated. Please update to Python 3.10 or above
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xf1feLxqhDc
# [youtube] xf1feLxqhDc: Downloading webpage
# [youtube] xf1feLxqhDc: Downloading android player API JSON
# WARNING: [youtube] xf1feLxqhDc: android client https formats require a GVS PO Token which was not provided. They will be skipped as they may yield HTTP Error 403. You can manually pass a GVS PO Token for this client with --extractor-args "youtube:po_token=android.gvs+XXX". For more information, refer to  https://github.com/yt-dlp/yt-dlp/wiki/PO-Token-Guide
# WARNING: [youtube] xf1feLxqhDc: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [info] xf1feLxqhDc: Downloading 1 format(s): 18
# [download] Sleeping 6.00 seconds as required by the site...
# [download] Destination: [KR⧸JP SUB] 민지(MINJI) - 踊り子(무희) ｜ 4k ｜ Odoriko by Vaundy ｜ 가사해석 ｜ 곰도리코 ｜ 오도리코.mp4
# [download] 100% of   14.73MiB in 00:00:07 at 1.96MiB/s

# %%
pip install -U yt-dlp
# Out:
# Requirement already satisfied: yt-dlp in c:\users\user\anaconda3\envs\mch\lib\site-packages (2025.10.14)
# Note: you may need to restart the kernel to use updated packages.
